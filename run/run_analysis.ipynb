# %% [markdown]
# ting

# %%
import pandas as pd
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Load your workout data file (adjust this path as needed)
file_path = '/Users/ngirmay/Documents/GitHub/ironman_retrospective/IronMan_2023/training_peaks/workouts.csv'
df = pd.read_csv(file_path)

# Filter for Run workouts
run_df = df[df['WorkoutType'] == 'Run'].sort_values('WorkoutDay')

# Convert meters to miles and calculate pace
run_df['DistanceInMiles'] = run_df['DistanceInMeters'] / 1609.34
run_df['PaceMinPerMile'] = (run_df['TimeTotalInHours'] * 60) / run_df['DistanceInMiles']

# Convert 'WorkoutDay' to datetime
run_df['WorkoutDay'] = pd.to_datetime(run_df['WorkoutDay'])

import pandas as pd
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Load your workout data file (adjust this path as needed)
file_path = '/Users/ngirmay/Documents/GitHub/ironman_retrospective/IronMan_2023/training_peaks/workouts.csv'
df = pd.read_csv(file_path)

# Filter for Run workouts
run_df = df[df['WorkoutType'] == 'Run'].sort_values('WorkoutDay')

# Convert meters to miles and calculate pace
run_df['DistanceInMiles'] = run_df['DistanceInMeters'] / 1609.34
run_df['PaceMinPerMile'] = (run_df['TimeTotalInHours'] * 60) / run_df['DistanceInMiles']

# Convert 'WorkoutDay' to datetime
run_df['WorkoutDay'] = pd.to_datetime(run_df['WorkoutDay'])

# Define the highlight period
highlight_start_date = pd.to_datetime("2022-12-01")
highlight_end_date = pd.to_datetime("2023-02-25")
ironman_event_date = pd.to_datetime("2023-07-23")

# Convert dates to milliseconds for Plotly
highlight_start_ms = highlight_start_date.timestamp() * 1000
highlight_end_ms = highlight_end_date.timestamp() * 1000
ironman_event_ms = ironman_event_date.timestamp() * 1000

# --- Visualization 1: Pace and Distance Over Time ---
fig1 = go.Figure()

# Add Pace as a line plot (Primary Y-axis)
fig1.add_trace(go.Scatter(x=run_df['WorkoutDay'], y=run_df['PaceMinPerMile'],
                          mode='lines+markers', name='Pace (min/mile)', 
                          line=dict(color='#e63946'), yaxis='y1', connectgaps=True))

# Add Distance as a line plot (Secondary Y-axis)
fig1.add_trace(go.Scatter(x=run_df['WorkoutDay'], y=run_df['DistanceInMiles'],
                          mode='lines+markers', name='Distance (miles)', 
                          line=dict(color='#457b9d'), yaxis='y2', connectgaps=True))

# Add vertical lines to mark key events (Training Start, Ironman Event)
fig1.add_vline(x=highlight_start_ms, line_dash="dash", line_color="green", annotation_text="Training Start")
fig1.add_vline(x=ironman_event_ms, line_dash="dash", line_color="green", annotation_text="Ironman Event")

# Add a highlighted zone from December 2022 to February 25th, 2023
fig1.add_vrect(
    x0=highlight_start_ms, x1=highlight_end_ms,
    fillcolor="Orange", opacity=0.2, layer="below", line_width=0
)

# Update layout for dual y-axes and clarity
fig1.update_layout(
    title="Pace and Distance Over Time",
    xaxis=dict(title='Date'),
    yaxis=dict(title='Pace (min/mile)', titlefont=dict(color='#e63946')),
    yaxis2=dict(title='Distance (miles)', titlefont=dict(color='#457b9d'), overlaying='y', side='right'),
    plot_bgcolor='#f1faee',
    legend=dict(orientation="h", yanchor="bottom", y=1.02, xanchor="right", x=1)
)

# Show the first figure
fig1.show()

# --- Visualization 2: Heart Rate and Cadence Over Time ---
fig2 = go.Figure()

# Add Heart Rate as a line plot (Primary Y-axis)
fig2.add_trace(go.Scatter(x=run_df['WorkoutDay'], y=run_df['HeartRateAverage'],
                          mode='lines+markers', name='Heart Rate (bpm)', 
                          line=dict(color='#e63946'), yaxis='y1', connectgaps=True))

# Add Cadence as a line plot (Secondary Y-axis)
fig2.add_trace(go.Scatter(x=run_df['WorkoutDay'], y=run_df['CadenceAverage'],
                          mode='lines+markers', name='Cadence (spm)', 
                          line=dict(color='#457b9d'), yaxis='y2', connectgaps=True))

# Add vertical lines for Training Start and Ironman Event
fig2.add_vline(x=highlight_start_ms, line_dash="dash", line_color="green", annotation_text="Training Start")
fig2.add_vline(x=ironman_event_ms, line_dash="dash", line_color="green", annotation_text="Ironman Event")

# Add highlighted zone (same as in the first plot)
fig2.add_vrect(
    x0=highlight_start_ms, x1=highlight_end_ms,
    fillcolor="Orange", opacity=0.2, layer="below", line_width=0
)

# Update layout for dual y-axes and clarity
fig2.update_layout(
    title="Heart Rate and Cadence Over Time",
    xaxis=dict(title='Date'),
    yaxis=dict(title='Heart Rate (bpm)', titlefont=dict(color='#e63946')),
    yaxis2=dict(title='Cadence (spm)', titlefont=dict(color='#457b9d'), overlaying='y', side='right'),
    plot_bgcolor='#f1faee',
    legend=dict(orientation="h", yanchor="bottom", y=1.02, xanchor="right", x=1)
)

# Show the second figure
fig2.show()

# Summary statistics
print(f"Total number of runs: {len(run_df)}")
print(f"Total distance run: {run_df['DistanceInMiles'].sum():.2f} miles")
print(f"Average pace: {run_df['PaceMinPerMile'].mean():.2f} min/mile")
print(f"Average heart rate: {run_df['HeartRateAverage'].mean():.2f} bpm")
print(f"Average cadence: {run_df['CadenceAverage'].mean():.2f} spm")

# Calculate improvements
first_month = run_df.head(30)
last_month = run_df.tail(30)

pace_improvement = (first_month['PaceMinPerMile'].mean() - last_month['PaceMinPerMile'].mean()) / first_month['PaceMinPerMile'].mean() * 100
distance_improvement = (last_month['DistanceInMiles'].mean() - first_month['DistanceInMiles'].mean()) / first_month['DistanceInMiles'].mean() * 100
hr_improvement = (first_month['HeartRateAverage'].mean() - last_month['HeartRateAverage'].mean()) / first_month['HeartRateAverage'].mean() * 100
cadence_improvement = (last_month['CadenceAverage'].mean() - first_month['CadenceAverage'].mean()) / first_month['CadenceAverage'].mean() * 100

print(f"\nImprovements (comparing first and last 30 days):")
print(f"Pace improvement: {pace_improvement:.2f}%")
print(f"Average distance per run improvement: {distance_improvement:.2f}%")
print(f"Heart rate improvement: {hr_improvement:.2f}%")
print(f"Cadence improvement: {cadence_improvement:.2f}%")
# Out:
# Total number of runs: 88
# Total distance run: 274.53 miles
# Average pace: 10.03 min/mile
# Average heart rate: 149.95 bpm
# Average cadence: 69.08 spm
#
# Improvements (comparing first and last 30 days):
# Pace improvement: -0.22%
# Average distance per run improvement: 23.45%
# Heart rate improvement: 1.43%
# Cadence improvement: 0.09%

# %%
import pandas as pd
import plotly.express as px

# Load your workout data file
file_path = '/Users/ngirmay/Documents/GitHub/ironman_retrospective/IronMan_2023/apple_health/health_data_exported/HKWorkoutActivityTypeRunning_2024-04-99_18-31-37_SimpleHealthExportCSV.csv'
df = pd.read_csv(file_path, sep=',', skiprows=1)

# Convert startDate and endDate to datetime format
df['startDate'] = pd.to_datetime(df['startDate'])
df['endDate'] = pd.to_datetime(df['endDate'])

# Strip the ' m' suffix from the totalDistance column and convert it to numeric
df['totalDistance'] = pd.to_numeric(df['totalDistance'].str.replace(' m', ''), errors='coerce')

# Convert meters to miles
df['DistanceInMiles'] = df['totalDistance'] / 1609.34

# Filter the data to only include workouts before Feb 25, 2023
cutoff_date = pd.to_datetime("2023-02-25").tz_localize('UTC')
df_filtered = df[df['startDate'] < cutoff_date]

# Re-aggregate weekly mileage
weekly_mileage_bar = df_filtered.resample('W', on='startDate')['DistanceInMiles'].sum().reset_index()

# Create a bar plot for the weekly mileage with the specified color
fig = px.bar(weekly_mileage_bar, x='startDate', y='DistanceInMiles',
             title='Weekly Mileage Before February 25, 2023',
             labels={'DistanceInMiles': 'Miles', 'startDate': 'Date'},
             color_discrete_sequence=['#e63946'])

# Update the x-axis to show weekly dates more insightfully
fig.update_layout(
    xaxis=dict(
        tickmode='linear',
        dtick='M1',  # Set the tick step to 1 month for better insights
        tickformat="%b %d, %Y"  # Format the ticks to show as Month Day, Year
    )
)

# Show the updated bar plot
fig.show()


# --- Summary Statistics Calculation ---
# Total number of runs
total_runs = df_filtered.shape[0]

# Total distance run (in miles)
total_distance_run = df_filtered['DistanceInMiles'].sum()

# Calculate improvements (if any start and end periods are available, similar to your request)
first_30_days = df_filtered[df_filtered['startDate'] < cutoff_date - pd.DateOffset(days=60)]
last_30_days = df_filtered[df_filtered['startDate'] >= cutoff_date - pd.DateOffset(days=30)]

# Average distance per run improvement
if not first_30_days.empty and not last_30_days.empty:
    avg_dist_first_30 = first_30_days['DistanceInMiles'].mean()
    avg_dist_last_30 = last_30_days['DistanceInMiles'].mean()
    distance_improvement = ((avg_dist_last_30 - avg_dist_first_30) / avg_dist_first_30) * 100
else:
    distance_improvement = "N/A"

# Print summary statistics
print(f"Total number of runs: {total_runs}")
print(f"Total distance run: {total_distance_run:.2f} miles")
print(f"\nImprovements (comparing first and last 30 days):")
print(f"Average distance per run improvement: {distance_improvement:.2f}%")
# Out:
# Total number of runs: 69
# Total distance run: 310.15 miles
#
# Improvements (comparing first and last 30 days):
# Average distance per run improvement: 75.67%

# %%
import pandas as pd
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import numpy as np

# Load the dataset
file_path = '/Users/ngirmay/Documents/GitHub/ironman_retrospective/IronMan_2023/apple_health/health_data_exported/HKWorkoutActivityTypeRunning_2024-04-99_18-31-37_SimpleHealthExportCSV.csv'
df = pd.read_csv(file_path, skiprows=1)

# Clean and process the relevant columns
df['totalEnergyBurned'] = pd.to_numeric(df['totalEnergyBurned'].str.split().str[0], errors='coerce')
df['totalDistance'] = pd.to_numeric(df['totalDistance'].str.split().str[0], errors='coerce') / 1609.34  # Convert meters to miles
df['duration'] = df['duration'] / 60  # Convert seconds to minutes
df['PaceMinPerMile'] = df['duration'] / df['totalDistance']
df['CaloriesPerMile'] = df['totalEnergyBurned'] / df['totalDistance']
df['startDate'] = pd.to_datetime(df['startDate'])
df['temperature'] = pd.to_numeric(df['HKWeatherTemperature'].str.split().str[0], errors='coerce')
df['elevationGain'] = pd.to_numeric(df['HKElevationAscended'].str.split().str[0], errors='coerce') / 100  # Convert cm to m

# Remove outliers and NaN values
df_clean = df.dropna(subset=['PaceMinPerMile', 'CaloriesPerMile', 'totalDistance'])

# Create subplots
fig = make_subplots(rows=3, cols=2, subplot_titles=("Calories Burned per Mile vs. Pace", 
                                                    "Calorie Efficiency Over Time",
                                                    "Impact of Temperature on Calorie Burn",
                                                    "Impact of Elevation Gain on Calorie Burn",
                                                    "Weekly Running Stats"),
                    specs=[[{}, {}],
                           [{}, {}],
                           [{"colspan": 2}, None]],
                    vertical_spacing=0.1,
                    horizontal_spacing=0.1)

# Define color scale
color_scale = [[0, "#457b9d"], [0.5, "white"], [1, "#e63946"]]

# Function to create scatter plot
def create_scatter(x, y, size, color, name, colorbar_title):
    return go.Scatter(
        x=x, y=y, 
        mode='markers', 
        name=name,
        marker=dict(
            size=size, 
            color=color, 
            colorscale=color_scale,
            colorbar=dict(title=colorbar_title, y=0.5, len=0.4),
            showscale=(name == 'Runs')  # Only show colorbar for the first plot
        ),
        text=df_clean['totalDistance'].round(2),
        hovertemplate='%{x}<br>Calories/Mile: %{y:.2f}<br>Distance: %{text} miles<extra></extra>'
    )

# 1. Calories per Mile vs. Pace
fig.add_trace(create_scatter(df_clean['PaceMinPerMile'], df_clean['CaloriesPerMile'], 
                             df_clean['totalDistance']*2, df_clean['totalDistance'], 
                             'Runs', 'Distance (miles)'), row=1, col=1)

# 2. Time Series of Calorie Efficiency
fig.add_trace(create_scatter(df_clean['startDate'], df_clean['CaloriesPerMile'], 
                             df_clean['totalDistance']*2, df_clean['totalDistance'], 
                             'Calorie Efficiency', ''), row=1, col=2)

# 3. Impact of Temperature on Calorie Burn
fig.add_trace(create_scatter(df_clean['temperature'], df_clean['CaloriesPerMile'], 
                             df_clean['totalDistance']*2, df_clean['totalDistance'], 
                             'Temperature Impact', ''), row=2, col=1)

# 4. Impact of Elevation Gain on Calorie Burn
fig.add_trace(create_scatter(df_clean['elevationGain'], df_clean['CaloriesPerMile'], 
                             df_clean['totalDistance']*2, df_clean['totalDistance'], 
                             'Elevation Impact', ''), row=2, col=2)

# 5. Weekly Running Stats
weekly_stats = df_clean.groupby(df_clean['startDate'].dt.to_period('W')).agg({
    'totalDistance': 'sum',
    'totalEnergyBurned': 'sum',
    'duration': 'sum'
}).reset_index()
weekly_stats['AvgPace'] = weekly_stats['duration'] / weekly_stats['totalDistance']
weekly_stats['startDate'] = weekly_stats['startDate'].astype(str)

fig.add_trace(go.Bar(
    x=weekly_stats['startDate'], 
    y=weekly_stats['totalDistance'],
    name='Weekly Distance', 
    marker_color='#457b9d'
), row=3, col=1)

fig.add_trace(go.Scatter(
    x=weekly_stats['startDate'], 
    y=weekly_stats['AvgPace'],
    name='Avg Weekly Pace', 
    yaxis='y2', 
    line=dict(color='#e63946')
), row=3, col=1)

# Update layout
fig.update_layout(height=1400, width=1200, title_text="Enhanced Running Data Analysis")
fig.update_xaxes(title_text="Pace (min/mile)", row=1, col=1)
fig.update_xaxes(title_text="Date", row=1, col=2)
fig.update_xaxes(title_text="Temperature (°F)", row=2, col=1)
fig.update_xaxes(title_text="Elevation Gain (m)", row=2, col=2)
fig.update_xaxes(title_text="Week", row=3, col=1)
fig.update_yaxes(title_text="Calories Burned per Mile", row=1, col=1)
fig.update_yaxes(title_text="Calories Burned per Mile", row=1, col=2)
fig.update_yaxes(title_text="Calories Burned per Mile", row=2, col=1)
fig.update_yaxes(title_text="Calories Burned per Mile", row=2, col=2)
fig.update_yaxes(title_text="Weekly Distance (miles)", row=3, col=1)
fig.update_yaxes(title_text="Avg Weekly Pace (min/mile)", secondary_y=True, row=3, col=1)

# Add dropdown for color coding
updatemenus = [
    dict(
        buttons=list([
            dict(label="Distance",
                 method="update",
                 args=[{"marker.color": [df_clean['totalDistance'], df_clean['totalDistance'], df_clean['totalDistance'], df_clean['totalDistance']],
                        "marker.colorscale": [color_scale, color_scale, color_scale, color_scale],
                        "marker.colorbar": [dict(title="Distance (miles)"), dict(title=""), dict(title=""), dict(title="")]
                       }]),
            dict(label="Pace",
                 method="update",
                 args=[{"marker.color": [df_clean['PaceMinPerMile'], df_clean['PaceMinPerMile'], df_clean['PaceMinPerMile'], df_clean['PaceMinPerMile']],
                        "marker.colorscale": [color_scale, color_scale, color_scale, color_scale],
                        "marker.colorbar": [dict(title="Pace (min/mile)"), dict(title=""), dict(title=""), dict(title="")]
                       }]),
            dict(label="Calories",
                 method="update",
                 args=[{"marker.color": [df_clean['totalEnergyBurned'], df_clean['totalEnergyBurned'], df_clean['totalEnergyBurned'], df_clean['totalEnergyBurned']],
                        "marker.colorscale": [color_scale, color_scale, color_scale, color_scale],
                        "marker.colorbar": [dict(title="Calories Burned"), dict(title=""), dict(title=""), dict(title="")]
                       }]),
        ]),
        direction="down",
        pad={"r": 10, "t": 10},
        showactive=True,
        x=0.9,
        xanchor="left",
        y=1.1,
        yanchor="top"
    ),
]

fig.update_layout(updatemenus=updatemenus)

# Adjust layout to prevent overlap
fig.update_layout(margin=dict(r=80, t=150), showlegend=True, 
                  legend=dict(orientation="h", yanchor="bottom", y=1.02, xanchor="right", x=1))

# Show the figure
fig.show()
# Out:
# /var/folders/_w/k9b4brpx7hlfjm6btrrr148r0000gn/T/ipykernel_27440/2518126169.py:76: UserWarning:
#
# Converting to PeriodArray/Index representation will drop timezone information.
